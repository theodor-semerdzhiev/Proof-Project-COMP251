# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('../BinTree_out.csv')
n_data = np.arange(0,999)
n_data = [x*100 for x in n_data]

# %%
n_vals = np.arange(1,100001)
logn_vals = np.log2(n_vals)

# %%
fig, ax = plt.subplots()
ax.plot(n_vals, logn_vals, label='f(n) = 2.5∙n∙log(n)')

ax.set_xscale('log')
ax.scatter(n_data, data, s=0.5, c='orange',label='Node Deletion BST Runtime')
ax.set_xlabel('Input Size n', fontsize=12)
ax.set_ylabel('Runtime (ns)', fontsize=12)
plt.ylim(-1,100)
plt.xlim(-1,2000000)

plt.legend(markerscale=5, loc='upper right')
plt.title('Time Complexity of node deletion of entire Binary Tree')
plt.ticklabel_format(useMathText=True, axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Theodor Semerdzhiev\AppData\Local\Temp\ipykernel_1628\2161690688.py:9: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(-1,2000000)
